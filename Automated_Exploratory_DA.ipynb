# %% [markdown]
# # AUTOMATED EDA COURSE

# %% [markdown]
# ***Objective:*** performaing auto Exploratory data analysis on car car data
#
# #### Package used:
# 1. AutoViz
# 2. Pandas-profiling

# %% [markdown]
# ## AutoViz implementation

# %%
pip install autoviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
# IMport Autovise Liabrary
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported v0.1.803. After importing autoviz, you must run '%matplotlib inline' to display charts inline.
#     AV = AutoViz_Class()
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
df = pd.read_csv("cardata.csv")

# %%
#This makes the plot to be displayed in thesame cell as the code
# %matplotlib inline

# %%
# For AutoViz
AV = AutoViz_Class()
report = AV.AutoViz(filename="cardata.csv")
# Out:
# Shape of your Data Set loaded: (11914, 16)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  4
#     Number of String-Categorical Columns =  7
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  1
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     16 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...

# %% [markdown]
# ## Automated generated summary
# Here's a summary of the observations:
#
# 1. SHAPE: Number of Rows and Columns: Your dataset has 11914 rows and 16 columns.
#
# #### Variable Classification:
#
#     - Numeric Columns: 3
#     - Integer-Categorical Columns: 4
#     - String-Categorical Columns: 7
#     - Date Time Columns: 1
#     - Discrete String Columns: 1
#     - Data Quality Issues:
#
# Several columns have missing values that need to be handled (e.g., imputation with mean, median, mode, or a constant value).
# Some columns contain outliers beyond the upper or lower bounds, which might need capping or removal.
# Certain columns contain high cardinality, rare categories, or mixed data types, suggesting possible data transformation or dropping of categories.
# There are duplicate rows present in the dataset.
# Specific Column Issues:
#
# Examples:
# 'Make' has 19 rare categories.
# 'Model' has a high cardinality with 915 unique values.
# 'Engine HP' and 'Engine Cylinders' have missing values and outliers.
# 'Market Category' has 3376 missing values and 53 rare categories.
# 'city mpg' and 'highway MPG' have outliers and a high correlation.

# %% [markdown]
# ## Auto EDA With SweetViz

# %% [markdown]
# ### Install sweetViz package

# %%
pip install sweetviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv

# %% [markdown]
# ## Loading preprocessed car data
# Processing the data beforhand reduces the complexity of the excution.

# %%
data = pd.read_csv('clean_car.csv')

# %% [markdown]
# ## Generating sweetviz report

# %%
Report = sv.analyze(data)
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %% [markdown]
# ## loading eda report into html_link

# %%
Report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Converting html report link to pdf for readability

# %%
pip install pdfkit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfkit

# %%
html_report= r'C:\Users\timay\OneDrive\Desktop\GIt_personal\Data_Preperation-\EDA-\SWEETVIZ_REPORT.html'

# %%
Save_path = 'file:///C:/Users/timay/OneDrive/Desktop/GIt_personal/Data_Preperation-/EDA-/sweetviz_report.pdf'

# %%
pip install wkhtmltopdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
config = pdfkit.configuration(wkhtmltopdf=r'C:\Users\timay\AppData\Local\pip\cache\wheels\61\e8\ba\34bacc3d874358dc176fd67cc97eeaa9a7fb54c55479258fb8\wkhtmltopdf-0.2-py3-none-any.whl')

# %%
#pdfkit.from_file(html_report, Save_path, configuration=config)

# %% [markdown]
# # Auto Eda with D-tale

# %%
pip install dtale
# Out:
# ...
#
#   Obtaining dependency information for dtale from https://files.pythonhosted.org/packages/c1/c3/766dc62ec7002289209c565638fb84120c420937157d24515b4575b1c7ac/dtale-3.9.0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/62.3 kB ? eta -:--:--
#      ---------------------------------------- 62.3/62.3 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ----------------------------------- - 614.4/642.7 kB 12.9 MB/s eta 0:00:01
#      ------------------------------------- 642.7/642.7 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
import dtale

# %%
data.head(2)
# Out:
#   Make    Model     Year       Engine Fuel Type        Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)    335.0
# 1  BMW    1 Series  2011  premium unleaded (required)    300.0
#
#    Engine Cylinders Transmission Type   Driven_Wheels    Number of Doors  \
# 0         6.0             MANUAL       rear wheel drive        2.0
# 1         6.0             MANUAL       rear wheel drive        2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity  MSRP
# 0    Compact           Coupe      26          19        3916     46135
# 1    Compact     Convertible      28          19        3916     40650

# %%
report= dtale.show(data)

# %%
report
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-E459QFP:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2024-01-11 13:03:02,087 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-01-11 13:03:02,104 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-01-11 13:03:02,104 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-01-11 13:03:02,120 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-01-11 13:03:02,121 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-01-11 13:03:02,121 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-01-11 13:03:02,121 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-01-11 13:03:02,121 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-01-11 13:03:02,121 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...

# %% [markdown]
# # Auto Eda with Dataprep

# %%
#pip install dataprep

# %%
#from dataprep.eda import create_report

# %%
#report = create_report(data)

# %%
pip install pandas_profiling

# %%
#from pandas_profiling import ProfileReport

# %%
# mitosheet auto eda
# klib

# %% [markdown]
# file:///C:/Users/timay/OneDrive/Desktop/GIt_personal/Data_Preperation-/EDA-/SWEETVIZ_REPORT.html

# %%
# Installing pandas profiing package
pip install pandas-profiling
# Out:
#   Cell In[19], line 2
#     pip install pandas-profiling
#         ^
# SyntaxError: invalid syntax
